# %% [markdown]
# # Immuno project

# %%
# Pandas for managing datasets
import pandas as pd

# Matplotlib for additional customization
from matplotlib import pyplot as plt
# %matplotlib inline

# Seaborn for plotting and styling
import seaborn as sns

# load data
dataframe = pd.read_csv("HabitatsReducedTrain.csv", na_values='?')
dataset = dataframe.values
dataframeTest = pd.read_csv("HabitatsReducedVal.csv", na_values='?')
datasetTest = dataframeTest.values

# split into input (X) and output (Y) variables
X_train = dataset[:,0:31]
y_train = dataset[:,32]

X_test = datasetTest[:,0:31]
y_test = datasetTest[:,32]


sns.lmplot(x="Days", y="Habitat 1 Fluid", hue="PID", fit_reg=False, data=dataframe, palette="cubehelix")
# sns.lmplot(x="Days", y="Habitat 2 Edema", hue="PID", fit_reg=False, data=dataframe, palette="cubehelix")
# sns.lmplot(x="Days", y="Habitat 3 Hemorrhage", hue="PID", fit_reg=False, data=dataframe, palette="cubehelix")
# sns.lmplot(x="Days", y="Habitat 4 GM", hue="PID", fit_reg=False, data=dataframe, palette="cubehelix")
# sns.lmplot(x="Days", y="Habitat 5 WM", hue="PID", fit_reg=False, data=dataframe, palette="cubehelix")
# sns.lmplot(x="Days", y="Habitat 6 Blood Vessels", hue="PID", fit_reg=False, data=dataframe, palette="cubehelix")
# sns.lmplot(x="Days", y="Habitat 9 Tmr Non Enh", hue="PID", fit_reg=False, data=dataframe, palette="cubehelix")
# sns.lmplot(x="Days", y="Habitat 10 Tumor Enhancing", hue="PID", fit_reg=False, data=dataframe, palette="cubehelix")

# plt.show()

# %%
sns.lmplot(x="Days", y="Habitat 2 Edema", hue="PID", fit_reg=False, data=dataframe, palette="cubehelix")

# %%
sns.lmplot(x="Days", y="Habitat 3 Hemorrhage", hue="PID", fit_reg=False, data=dataframe, palette="cubehelix")

# %%
sns.lmplot(x="Days", y="Habitat 4 GM", hue="PID", fit_reg=False, data=dataframe, palette="cubehelix")

# %%
sns.lmplot(x="Days", y="Habitat 5 WM", hue="PID", fit_reg=False, data=dataframe, palette="cubehelix")

# %%
sns.lmplot(x="Days", y="Habitat 6 Blood Vessels", hue="PID", fit_reg=False, data=dataframe, palette="cubehelix")

# %%
sns.lmplot(x="Days", y="Habitat 9 Tmr Non Enh", hue="PID", fit_reg=False, data=dataframe, palette="cubehelix")

# %%
sns.lmplot(x="Days", y="Habitat 10 Tumor Enhancing", hue="PID", fit_reg=False, data=dataframe, palette="cubehelix")

# %%
# Pre-format DataFrame
one_df = dataframe.truncate(after=10)
sns.lmplot(x="Days", y="Habitat 10 Tumor Enhancing", data=one_df, palette="cubehelix")
